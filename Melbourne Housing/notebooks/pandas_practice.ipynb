# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/housing/melb_data.csv')

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
region_name = df['Regionname']
region_name.head(10)
# Out:
# 0    Northern Metropolitan
# 1    Northern Metropolitan
# 2    Northern Metropolitan
# 3    Northern Metropolitan
# 4    Northern Metropolitan
# 5    Northern Metropolitan
# 6    Northern Metropolitan
# 7    Northern Metropolitan
# 8    Northern Metropolitan
# 9    Northern Metropolitan
# Name: Regionname, dtype: object

# %%
mcols = ['Suburb', 'Rooms']
type(mcols)
# Out:
# list

# %%
df_selection_cols = df[mcols]
df_selection_cols.describe()
# Out:
#               Rooms
# count  13580.000000
# mean       2.937997
# std        0.955748
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max       10.000000

# %%
df_selection_cols.groupby('Suburb').mean().head(10)
# Out:
#                    Rooms
# Suburb
# Abbotsford      2.410714
# Aberfeldie      3.090909
# Airport West    3.000000
# Albanvale       3.000000
# Albert Park     2.710145
# Albion          2.682927
# Alphington      3.029412
# Altona          2.959459
# Altona Meadows  3.333333
# Altona North    3.178571

# %%
rooms = df[df['Rooms'] > 3]
rooms
# Out:
#                Suburb           Address  Rooms Type      Price Method  \
# 4          Abbotsford       55a Park St      4    h  1600000.0     VB
# 20         Abbotsford   3/72 Charles St      4    h  1330000.0     PI
# 30         Abbotsford      31 Turner St      4    h  1542000.0      S
# 46       Airport West     36 Roberts Rd      4    h   785000.0      S
# 47       Airport West  11 Harrington Rd      6    h   725000.0     SP
# ...               ...               ...    ...  ...        ...    ...
# 13571  Wantirna South        15 Mara Cl      4    h  1330000.0      S
# 13573        Werribee       5 Nuragi Ct      4    h   635000.0      S
# 13575   Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13578    Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579      Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
rooms.groupby('Suburb')['Address'].head(5)
# Out:
# 4             55a Park St
# 20        3/72 Charles St
# 30           31 Turner St
# 46          36 Roberts Rd
# 47       11 Harrington Rd
#                ...
# 13485      36A Windsor Av
# 13494         21 David St
# 13536        4 Gellion Pl
# 13537       8 Kennedy Pde
# 13543    33 Moonstone Cct
# Name: Address, Length: 1116, dtype: object

# %%
def split_address(address):
    return address.split(' ')[2]

df['loc'] = df['Address'].apply(split_address)
df['loc']
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: loc, Length: 13580, dtype: object

# %%
df[df['loc'] == 'St'].groupby('Suburb')[['Rooms','Type', 'Price']].head(5)
# Out:
#        Rooms Type      Price
# 0          2    h  1480000.0
# 1          2    h  1035000.0
# 2          3    h  1465000.0
# 4          4    h  1600000.0
# 5          2    h   941000.0
# ...      ...  ...        ...
# 13456      4    h  1125000.0
# 13487      5    h   710000.0
# 13494      4    h   720000.0
# 13539      3    h   890000.0
# 13574      3    h   582000.0
#
# [1029 rows x 3 columns]

# %%
display(df.corr)
# Out:
# <bound method DataFrame.corr of               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# ...

# %%
df['Type'].unique()
# Out:
# array(['h', 'u', 't'], dtype=object)

# %%
df['Type'].value_counts()
# Out:
# h    9449
# u    3017
# t    1114
# Name: Type, dtype: int64

# %%
sns.barplot(data = df, x = 'Type', y = 'Price')
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Price'>

# %%
plt.figure(figsize=(16,8))
sns.countplot(data = df, x = 'Price')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='count'>
